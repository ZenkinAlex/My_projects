# %% [markdown]
# <a href="https://colab.research.google.com/github/ZenkinAlex/My_projects/blob/main/Test.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ## **Задание**
#
# Показать динамику международной торговли по продукту фтористый алюминий (код hs code 282612)
#
# Сайт
# Trade Map - Trade statistics for international business development
#
# Нужно самостоятельно зарегистрироваться (создать бесплатный логин и пароль)
#
# По указанном коду скачать данные за период 2018-2025 (в идеале спарсить в автоматическом режиме)
# - объемы (quantities)
# - цены (unit values)
#
# Показать крупнейших экспортеров и импортеров, в динамике со срезами изменений по годам (как по объемам, так и по ценам)
# - таблица
# - карта
#
# По крупнейшим экспортерам сделать срез по крупнейшим потребителям (по Италии использовать вкладку mirror data)
# - желательно в виде карты (желательно автоматическая карта, построенная с помощью библиотек python)
# - кому грузят и по каким ценам
#
# Сделать сравнение по основным экспортерам и импортерам
# - география поставок (объем по странам)
# - динамика цен от разных поставщиков для импортеров (или по разным потребителям для экспортеров)
#
# Все своды должны быть представлены в визуально понятной форме

# %% [markdown]
# ## **Решение**
# ### **Предисловие**
# У сайта нет api, а веб-скрэппингом парсить данные это не лучший вариант. Насколько я понял эта платформа берет данные здесь https://comtradedeveloper.un.org/signin?returnUrl=%2F и тут есть свой api https://comtradedeveloper.un.org/signin и описание на гите
# https://github.com/uncomtrade/comtradeapicall?spm=a2ty_o01.29997173.0.0.65cd5171WMneAp. Поэтому для автоматизации решил использовать эту платформу

# %% [markdown]
# ### **1. Установка библиотек**

# %%
# !pip install geopandas requests pandas numpy matplotlib seaborn plotly openpyxl comtradeapicall ipywidgets -q

import pandas as pd
import numpy as np
import comtradeapicall
from datetime import date
import plotly.express as px
import plotly.graph_objects as go
from plotly.subplots import make_subplots
import ipywidgets as widgets
from IPython.display import display, clear_output
import warnings
warnings.filterwarnings("ignore")


SUBSCRIPTION_KEY = "1fbfccefb0e8489db0a75c81db504ae8"
HS_CODE = "282612"
YEARS = list(range(2018, 2026))  # 2018–2025
MAX_RECORDS_PER_CALL = 250000  # лимит API

# %% [markdown]
# ### **2. Парсинг данных**

# %%
all_data = []

for year in YEARS:
    print(f"Загрузка данных за {year}...")
    try:
        df = comtradeapicall.getFinalData(
            subscription_key=SUBSCRIPTION_KEY,
            typeCode='C',          # Goods
            freqCode='A',          # Annual
            clCode='HS',           # Harmonized System
            period=str(year),
            reporterCode=None,     # Все страны-репортеры
            cmdCode=HS_CODE,
            flowCode=None,         # Все потоки (экспорт/импорт)
            partnerCode=None,
            partner2Code=None,
            customsCode=None,
            motCode=None,
            maxRecords=MAX_RECORDS_PER_CALL,
            format_output='JSON',
            includeDesc=True
        )
        if not df.empty:
            df['Year'] = year
            all_data.append(df)
        else:
            print(f"Нет данных за {year}")
    except Exception as e:
        print(f"Ошибка при загрузке {year}: {e}")

df_full = pd.concat(all_data, ignore_index=True)

# Сохраняем сырые данные на случай перезапуска
df_full.to_csv("fluoride_aluminium_282612_raw.csv", index=False)
# Out:
# Загрузка данных за 2018...
# Загрузка данных за 2019...
# Загрузка данных за 2020...
# Загрузка данных за 2021...
# Загрузка данных за 2022...
# Загрузка данных за 2023...
# Загрузка данных за 2024...
# Загрузка данных за 2025...

# %%
df_full.head()
# Out:
#   typeCode freqCode  refPeriodId  refYear  refMonth period  reporterCode  \
# 0        C        A     20180101     2018        52   2018            36
# 1        C        A     20180101     2018        52   2018            36
# 2        C        A     20180101     2018        52   2018            36
# 3        C        A     20180101     2018        52   2018            36
# 4        C        A     20180101     2018        52   2018            36
#
#   reporterISO reporterDesc flowCode  ... isNetWgtEstimated   grossWgt  \
# 0         AUS    Australia        X  ...              True     1689.0
# 1         AUS    Australia        X  ...              True     1689.0
# 2         AUS    Australia        X  ...              True  2768959.0
# 3         AUS    Australia        X  ...              True  2768959.0
# 4         AUS    Australia        X  ...             False  2767270.0
#
#   isGrossWgtEstimated cifvalue    fobvalue primaryValue legacyEstimationFlag  \
# 0               False      NaN   33595.032    33595.032                    6
# 1               False      NaN   33595.032    33595.032                    6
# 2               False      NaN  571482.404   571482.404                    6
# 3               False      NaN  571482.404   571482.404                    6
# 4               False      NaN  537887.372   537887.372                    0
#
#   isReported isAggregate  Year
# 0       True       False  2018
# 1      False        True  2018
# 2      False        True  2018
# 3      False        True  2018
# 4      False        True  2018
#
# [5 rows x 48 columns]

# %% [markdown]
# **Описание столбцов датасета**
#
# ***typeCode*** | Тип данных: 'C' = товары, 'S' = услуги
#
# ***freqCode*** | Частота: 'A' = годовые, 'M' = месячные
#
# ***refYear*** | Год наблюдения (например, 2023)
#
# ***refMonth*** | Месяц (1–12); для годовых данных = 0 или 12
#
# ***period*** | Строка периода: '2023' для годовых, '202305' для мая 2023
#
# ***reporterCode*** | Цифровой код страны-репортера по Comtrade (например, 842 = США)
#
# ***reporterISO*** | ISO 3166-alpha-3 код страны-репортера (например, 'USA')
#
# ***reporterDesc*** | Название страны-репортера (например, 'United States')
#
# ***flowCode*** | Код направления торговли: 'X' = экспорт, 'M' = импорт
#
# ***flowDesc*** | Описание потока: 'Export', 'Import'
#
# ***partnerCode*** | Цифровой код торгового партнёра (страны-получателя/отправителя)
#
# ***partnerISO*** | ISO 3166-alpha-3 код партнёра (например, 'RUS')
#
# ***partnerDesc*** | Название страны-партнёра
#
# ***partner2Code, partner2ISO, partner2Desc*** | Вторичный партнёр (редко используется; обычно None или агрегаты)
#
# ***cmdCode*** Код товара по HS (например, '282612' = фториды алюминия)
#
# ***cmdDesc*** | Описание товара на английском
#
# ***aggrLevel*** | Уровень агрегации в HS (6 = детальный, 4 = групповой и т.д.)
#
# ***isLeaf*** | True, если это конечный (не агрегированный) код HS
#
# ***netWgt*** | Чистый вес в килограммах (kg)
#
# ***isNetWgtEstimated*** | True, если вес оценён, а не измерен
#
# ***fobvalue*** | Стоимость экспорта в USD по условиям FOB (Free On Board)
#
# ***cifvalue*** | Стоимость импорта в USD по условиям CIF (Cost, Insurance, Freight)
#
# ***primaryValue*** | Основная стоимость: автоматически выбирает fobvalue для экспорта и cifvalue для импорта. Рекомендуется использовать именно её.
#
# ***qty*** | Количество в основной единице измерения (qtyUnitAbbr)
#
# ***qtyUnitCode*** | Код единицы измерения (например, 8 = кг, 15 = штуки)
#
# ***qtyUnitAbbr*** | Аббревиатура единицы измерения (например, 'kg', 'NAR')
#
# ***isQtyEstimated*** | Признак оценённого количества
# ***customsCode, customsDesc*** | Таможенная процедура (обычно 'C00' = стандартная)
#
# ***motCode, motDesc*** | Способ транспортировки (морской, воздушный и т.д.)
#
# ***isAggregate*** | True, если запись представляет агрегат (например, 'World', регионы)
#
# ***isReported*** | True, если данные предоставлены самой страной-репортером
#
# ***classificationCode*** |  Версия HS (например, 'H6' = HS 2022)
#
# ***Year*** | Дополнительное поле, добавленное вручную для удобства анализа

# %% [markdown]
# ### **3. Предобработка данных**

# %%
df_clean = df_full[
    (df_full['reporterISO'].notna()) &
    (df_full['partnerISO'].notna()) &
    (df_full['primaryValue'] > 0) &
    (df_full['netWgt'] > 0) &
    (df_full['partnerISO'] != 'WLD') &
    (df_full['reporterISO'] != 'WLD')
].copy()

# Расчёт цены за кг
df_clean['Price per kg (USD)'] = df_clean['primaryValue'] / df_clean['netWgt']

# Фильтр выбросов (реалистичный диапазон цен для AlF3: $0.5 – $10/kg - по данным на 16 января 2026 года, цена алюминия на LME составляла 3140,70 USD/т)
df_clean = df_clean[
    (df_clean['Price per kg (USD)'] >= 0.1) &
    (df_clean['Price per kg (USD)'] <= 50)
]

print(f"✅ После очистки: {len(df_clean)} записей")
# Out:
# ✅ После очистки: 18313 записей

# %% [markdown]
# ### **4. ТОП-5 стран по объему (kg) экспорта**

# %%
df_export = df_clean[df_clean['flowDesc'] == 'Export']
df_import = df_clean[df_clean['flowDesc'] == 'Import']

pivot_export_volume = df_export.pivot_table(
    index=['reporterDesc','reporterISO'],
    columns='refYear',
    values='netWgt',
    aggfunc='sum',
).reset_index()

year_columns = [col for col in pivot_export_volume.columns if col != 'reporterDesc' and col !='reporterISO']
pivot_export_volume['TOTAL'] = pivot_export_volume[year_columns].sum(axis=1)
pivot_export_volume = pivot_export_volume.sort_values('TOTAL', ascending=False).nlargest(5,'TOTAL')
pivot_export_volume
# Out:
# refYear          reporterDesc reporterISO         2018          2019  \
# 10                      China         CHN  211020930.0  1.877248e+08
# 51                    Tunisia         TUN   85776000.0  8.490900e+07
# 8                      Canada         CAN   35504732.0  1.154250e+08
# 54       United Arab Emirates         ARE   49243072.0  1.038520e+07
# 30                  Lithuania         LTU   26496840.0  2.631268e+07
#
# refYear         2020         2021          2022          2023          2024  \
# 10       195002742.0   95971608.0  2.222576e+08  2.396563e+08  2.681986e+08
# 51        66683000.0   79530000.0  7.936400e+07  5.232400e+07  7.862960e+07
# 8         13964920.0   10824080.0  5.878624e+07  4.202568e+07  5.544424e+06
# 54        23844796.0  105167622.0  3.168437e+07  3.008071e+07           NaN
# 30        33887640.0   40826360.0  7.248200e+06  1.531000e+06  2.346320e+07
#
# refYear  2025         TOTAL
# 10        NaN  1.419833e+09
# 51        NaN  5.272156e+08
# 8         NaN  2.820750e+08
# 54        NaN  2.504058e+08
# 30        NaN  1.597659e+08

# %%
# Столбчатая диаграмма
fig_bar = px.bar(
    pivot_export_volume.sort_values('TOTAL'),
    x='TOTAL',
    y='reporterDesc',
    orientation='h',
    title='ТОП-5 стран по объёму экспорта (кг)',
    labels={'TOTAL': 'Экспорт (кг)', 'reporterDesc': 'Страна'}
)

# Карта (с лог-шкалой)
pivot_export_volume['log_TOTAL'] = np.log10(pivot_export_volume['TOTAL'] + 1)
fig_map = px.choropleth(
    pivot_export_volume,
    locations='reporterISO',
    color='log_TOTAL',
    hover_name='reporterDesc',
    labels={'log_TOTAL': 'log₁₀(кг)'},
    projection='natural earth'
)

# Комбинируем
fig = make_subplots(
    rows=1, cols=2,
    column_widths=[0.6, 0.4],
    specs=[[{"type": "choropleth"}, {"type": "bar"}]]
)

for trace in fig_map.data:
    fig.add_trace(trace, row=1, col=1)
for trace in fig_bar.data:
    fig.add_trace(trace, row=1, col=2)

fig.update_layout(title_text="Экспорт", height=500)
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.35.2.min.js"></script>                <div id="e994de9c-9cea-4662-99fb-5a77d429650e" class="plotly-graph-div" style="height:500px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("e994de9c-9cea-4662-99fb-5a77d429650e")) {                    Plotly.newPlot(                        "e994de9c-9cea-4662-99fb-5a77d429650e",                        [{"coloraxis":"coloraxis","geo":"geo","hovertemplate":"\u003cb\u003e%{hovertext}\u003c\u002fb\u003e\u003cbr\u003e\u003cbr\u003ereporterISO=%{location}\u003cbr\u003elog₁₀(кг)=%{z}\u003cextra\u003e\u003c\u002fextra\u003e","hovertext":["China","Tunisia","Canada","United Arab Emirates","Lithuania"],"locations":["CHN","TUN","CAN","ARE","LTU"],"name":"","z":[9.15223714020079,8.721988252715697,8.450364653780845,8.398644320082028,8.203484147318186],"type":"choropleth"},{"alignmentgroup":"True","hovertemplate":"Экспорт (кг)=%{x}\u003cbr\u003eСтрана=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"","marker":{"color":"#636efa","pattern":{"shape":""}},"name":"","offsetgroup":"","orientation":"h","showlegend":false,"textposition":"auto","x":[159765920.0,250405762.17000002,282075036.0,527215599.51100004,1419832588.0479999],"xaxis":"x","y":["Lithuania","United Arab Emirates","Canada","Tunisia","China"],"yaxis":"y","type":"bar"}],                        {"template":{"data":{"histogram2dcontour":[{"type":"histogram2dcontour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"choropleth":[{"type":"choropleth","colorbar":{"outlinewidth":0,"ticks":""}}],"histogram2d":[{"type":"histogram2d","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmap":[{"type":"heatmap","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmapgl":[{"type":"heatmapgl","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"contourcarpet":[{"type":"contourcarpet","colorbar":{"outlinewidth":0,"ticks":""}}],"contour":[{"type":"contour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"surface":[{"type":"surface","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"mesh3d":[{"type":"mesh3d","colorbar":{"outlinewidth" ...

# %% [markdown]
# ### **5. ТОП-5 стран по объему (kg) импорта**

# %%
pivot_import_volume =df_import.pivot_table(
    index=['reporterDesc','reporterISO'],
    columns='refYear',
    values='netWgt',
    aggfunc='sum',
).reset_index()

year_columns = [col for col in pivot_import_volume.columns if col != 'reporterDesc'and col !='reporterISO']
pivot_import_volume['TOTAL'] = pivot_import_volume[year_columns].sum(axis=1)
pivot_import_volume = pivot_import_volume.sort_values('TOTAL', ascending=False).nlargest(5,'TOTAL')
pivot_import_volume
# Out:
# refYear  reporterDesc reporterISO          2018          2019          2020  \
# 63         Mozambique         MOZ  4.871829e+09  3.780891e+09  9.322958e+09
# 18             Canada         CAN  1.995863e+08  1.268382e+08  1.551723e+08
# 43              India         IND  1.175261e+08  9.415795e+07  1.080499e+08
# 91       South Africa         ZAF  1.180915e+08  8.083641e+07  1.212085e+08
# 3           Australia         AUS  7.336534e+07  1.079728e+08  9.376194e+07
#
# refYear          2021          2022          2023          2024  2025  \
# 63       8.478513e+09  1.913268e+10  1.567264e+10  1.397695e+09   NaN
# 18       2.368324e+08  1.889218e+08  2.449042e+08  3.615595e+08   NaN
# 43       1.334679e+08  1.331817e+08  1.558316e+08  1.595054e+08   NaN
# 91       9.455378e+07  1.476870e+08  9.058044e+07  1.091395e+08   NaN
# 3        9.721496e+07  1.306305e+08  8.665600e+07  9.456000e+07   NaN
#
# refYear         TOTAL
# 63       6.265720e+10
# 18       1.513815e+09
# 43       9.017206e+08
# 91       7.620971e+08
# 3        6.841615e+08

# %%
# Столбчатая диаграмма
fig_bar = px.bar(
    pivot_import_volume.sort_values('TOTAL'),
    x='TOTAL',
    y='reporterDesc',
    orientation='h',
    title='ТОП-5 стран по объёму импорта (кг)',
    labels={'TOTAL': 'Экспорт (кг)', 'reporterDesc': 'Страна'}
)

# Карта (с лог-шкалой)
pivot_import_volume['log_TOTAL'] = np.log10(pivot_export_volume['TOTAL'] + 1)
fig_map = px.choropleth(
    pivot_import_volume,
    locations='reporterISO',
    color='log_TOTAL',
    hover_name='reporterDesc',
    labels={'log_TOTAL': 'log₁₀(кг)'},
    projection='natural earth'
)

# Комбинируем
fig = make_subplots(
    rows=1, cols=2,
    column_widths=[0.6, 0.4],
    specs=[[{"type": "choropleth"}, {"type": "bar"}]]
)

for trace in fig_map.data:
    fig.add_trace(trace, row=1, col=1)
for trace in fig_bar.data:
    fig.add_trace(trace, row=1, col=2)

fig.update_layout(title_text="Импорт", height=500)
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.35.2.min.js"></script>                <div id="5813e33f-f0b7-4435-a0d5-6f0aa729e134" class="plotly-graph-div" style="height:500px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("5813e33f-f0b7-4435-a0d5-6f0aa729e134")) {                    Plotly.newPlot(                        "5813e33f-f0b7-4435-a0d5-6f0aa729e134",                        [{"coloraxis":"coloraxis","geo":"geo","hovertemplate":"\u003cb\u003e%{hovertext}\u003c\u002fb\u003e\u003cbr\u003e\u003cbr\u003ereporterISO=%{location}\u003cbr\u003elog₁₀(кг)=%{z}\u003cextra\u003e\u003c\u002fextra\u003e","hovertext":["Mozambique","Canada","India","South Africa","Australia"],"locations":["MOZ","CAN","IND","ZAF","AUS"],"name":"","z":[null,null,null,null,null],"type":"choropleth"},{"alignmentgroup":"True","hovertemplate":"Экспорт (кг)=%{x}\u003cbr\u003eСтрана=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"","marker":{"color":"#636efa","pattern":{"shape":""}},"name":"","offsetgroup":"","orientation":"h","showlegend":false,"textposition":"auto","x":[684161542.64,762097115.86,901720575.018,1513814752.0,62657203087.52],"xaxis":"x","y":["Australia","South Africa","India","Canada","Mozambique"],"yaxis":"y","type":"bar"}],                        {"template":{"data":{"histogram2dcontour":[{"type":"histogram2dcontour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"choropleth":[{"type":"choropleth","colorbar":{"outlinewidth":0,"ticks":""}}],"histogram2d":[{"type":"histogram2d","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmap":[{"type":"heatmap","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmapgl":[{"type":"heatmapgl","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"contourcarpet":[{"type":"contourcarpet","colorbar":{"outlinewidth":0,"ticks":""}}],"contour":[{"type":"contour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"surface":[{"type":"surface","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"mesh3d":[{"type":"mesh3d","colorbar":{"outlinewidth":0,"ticks":""}}],"scatter":[{"fillpattern":{"fillmode":"overlay","size":10,"solidity":0 ...

# %% [markdown]
# ### **6. Интерактивный виджет для среза по крупнейшим потребителям**

# %% [markdown]
# ### **7. Cравнение по основным экспортерам и импортерам**

# %%
# Получим ТОП-5 экспортёров по совокупному объёму за весь период
top_exporters = pivot_export_volume['reporterISO'].tolist()

# Фильтруем данные только по этим экспортёрам
df_top_export_flows = df_export[df_export['reporterISO'].isin(top_exporters)]

# Агрегируем по экспортёру и партнёру
geo_supply = df_top_export_flows.groupby(['reporterDesc', 'partnerDesc', 'partnerISO'])['netWgt'].sum().reset_index()
geo_supply = geo_supply.sort_values('netWgt', ascending=False)

# Визуализация: карта потоков (choropleth + scatter)
fig = px.scatter_geo(
    geo_supply,
    locations="partnerISO",
    size="netWgt",
    color="reporterDesc",
    hover_name="partnerDesc",
    projection="natural earth",
    title="География поставок: куда поставляют ТОП-5 экспортёров фтористого алюминия (2018–2025)"
)
fig.update_layout(height=600)
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.35.2.min.js"></script>                <div id="8eede090-9a22-4c72-a353-5eecf7f89bbb" class="plotly-graph-div" style="height:600px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("8eede090-9a22-4c72-a353-5eecf7f89bbb")) {                    Plotly.newPlot(                        "8eede090-9a22-4c72-a353-5eecf7f89bbb",                        [{"geo":"geo","hovertemplate":"\u003cb\u003e%{hovertext}\u003c\u002fb\u003e\u003cbr\u003e\u003cbr\u003ereporterDesc=China\u003cbr\u003enetWgt=%{marker.size}\u003cbr\u003epartnerISO=%{location}\u003cextra\u003e\u003c\u002fextra\u003e","hovertext":["World","India","Australia","Malaysia","Russian Federation","United Arab Emirates","Bahrain","New Zealand","Brazil","Kazakhstan","Mozambique","Rep. of Korea","South Africa","Canada","Venezuela","Japan","Ghana","USA","Indonesia","Iran","Qatar","Cameroon","Türkiye","Egypt","Argentina","Oman","China, Hong Kong SAR","Thailand","Tajikistan","Other Asia, nes","Spain","Netherlands","Dem. People's Rep. of Korea","Viet Nam","Slovenia","Italy","Germany","Czechia","Philippines","Mali","United Kingdom","France","Guinea","Israel","Poland"],"legendgroup":"China","locations":["W00","IND","AUS","MYS","RUS","ARE","BHR","NZL","BRA","KAZ","MOZ","KOR","ZAF","CAN","VEN","JPN","GHA","USA","IDN","IRN","QAT","CMR","TUR","EGY","ARG","OMN","HKG","THA","TJK","S19","ESP","NLD","PRK","VNM","SVN","ITA","DEU","CZE","PHL","MLI","GBR","FRA","GIN","ISR","POL"],"marker":{"color":"#636efa","size":[709916294.0239999,135909645.0,126112660.0,78233420.0,59158800.0,41950331.0,39600540.0,34144022.0,29486775.0,22954620.0,19384680.0,17999251.0,17514720.0,15556750.0,8470140.0,8197856.0,8103025.0,7547732.691,7512133.0,6374479.0,5508000.0,4508960.0,3986000.0,3908000.0,2250000.0,2000000.0,1650923.0,678075.0,602200.0,178052.0,111006.0,106013.0,59970.0,52500.0,50000.0,25500.0,9735.0,6200.0,5000.0,2942.0,2900.0,2091.263,641.07,5.0,1.0],"sizemode":"area","sizeref":1774790.7350599999,"symbol":"circle"},"mode":"markers","name":"China","showlegend":true,"type":"scattergeo"},{"geo":"geo","hovertemplate":"\u003cb\u003e%{hovertext}\u003c\u002fb\u003e\u003cbr\u003e\u003cbr\u003ereporterDesc=Tunisia\u003cbr\u003enetWgt=%{marker.size}\u003cbr\u003epartnerISO=%{location}\u003cextra\u003e\u003c\u002fextra\u003e","hovertext":["World","United Arab Emirates","South Africa","Egypt","Russian Federation","Qatar","Oman","Brazil","Greece","Canada","Malaysia","Netherlands","Türkiye","France","Ghana","Cameroon"],"legendgroup":"Tunisia","locations":["W00","ARE","ZAF","EGY","RUS","QAT","OMN","BRA","GRC","CAN","MYS","NLD","TUR","FRA","GHA","CMR"],"marker":{"color":"#EF553B","size":[263607799.755,48594226.733,46587111.778,35746223.675,34560000.0,32070823.739,21930000.0,12375083.701,10966271.703,8730547.533,4704000.0,2877046.94,1500000.0,1484463.954,1020000.0,462000.0],"sizemode":"area","sizeref":1774790.7350599999,"symbol":"circle"},"mode":"markers","name":"Tunisia","showlegend":true,"type":"scattergeo"},{"geo":"geo","hovertemplate":"\u003cb\u003e%{hovertext}\u003c\u002fb\u003e\u003cbr\u003e\u003cbr\u003ereporterDesc=Canada\u003cbr\u003enetWgt=%{marker.size}\u003cbr\u003epartnerISO=%{location}\u003cextra\u003e\u003c\u002fextra\u003e","hovertext":["World","USA","Japan","France"],"legendgroup":"Canada","locations":["W00","USA","JPN","FRA"],"marker":{"color":"#00cc96","size":[141037518.0,140159238.0,872284.0,5996.0],"sizemode":"area","sizeref":1774790.7350599999,"symbol":"circle"},"mode":"markers","name":"Canada","showlegend":true,"type":"scattergeo"},{"geo":"geo","hovertemplate":"\u003cb\u003e%{hovertext}\u003c\u002fb\u003e\u003cbr\u003e\u003cbr\u003ereporterDesc=United Arab Emirates\u003cbr\u003enetWgt=%{marker.size}\u003cbr\u003epartnerISO=%{location}\u003cextra\u003e\u003c\u002fextra\u003e","hovertext":["Wo ...

# %%
top_importers = pivot_import_volume['reporterISO'].head(3).tolist()
top_importer_names = pivot_import_volume['reporterDesc'].head(3).tolist()
print("ТОП-3 импортёра:", top_importer_names)
# Out:
# ТОП-3 импортёра: ['Mozambique', 'Canada', 'India']

# %%
# 1. Агрегируем импорт по году, импортёру и поставщику
df_import_agg = df_import.groupby([
    'reporterDesc', 'reporterISO', 'partnerDesc', 'partnerISO', 'refYear'
]).agg({
    'netWgt': 'sum',
    'primaryValue': 'sum'
}).reset_index()

# Пересчитываем цену
df_import_agg['Price per kg (USD)'] = df_import_agg['primaryValue'] / df_import_agg['netWgt']
df_import_agg = df_import_agg[
    (df_import_agg['Price per kg (USD)'] >= 0.1) &
    (df_import_agg['Price per kg (USD)'] <= 50)
]

# 2. Определяем ТОП-5 поставщиков для каждого из ТОП-3 импортёров
top_importers_list = pivot_import_volume['reporterISO'].head(3).tolist()

# Список пар (ImporterISO, ExporterISO), которые войдут в график
top_supplier_pairs = []

for importer_iso in top_importers_list:
    importer_data = df_import_agg[df_import_agg['reporterISO'] == importer_iso]
    # Совокупный объём по поставщику
    supplier_totals = importer_data.groupby(['partnerISO', 'partnerDesc'])['netWgt'].sum().reset_index()
    top5 = supplier_totals.nlargest(5, 'netWgt')
    for _, row in top5.iterrows():
        top_supplier_pairs.append((importer_iso, row['partnerISO']))

# Преобразуем в set для быстрой фильтрации
top_supplier_set = set(top_supplier_pairs)

# 3. Фильтруем агрегированные данные
df_plot = df_import_agg[
    df_import_agg[['reporterISO', 'partnerISO']].apply(tuple, axis=1).isin(top_supplier_set)
].copy()

# Переименуем для графика
df_plot.rename(columns={
    'reporterDesc': 'Importer',
    'partnerDesc': 'Exporter'
}, inplace=True)

# 4. Построение графика
if not df_plot.empty:
    fig = px.line(
        df_plot,
        x='refYear',
        y='Price per kg (USD)',
        color='Exporter',
        facet_col='Importer',
        facet_col_wrap=1,
        markers=True,
        title="Динамика цен (USD/kg) у ТОП-3 импортёров по ключевым поставщикам (2018–2025)"
    )

    # Ограничиваем ось Y, чтобы выбросы не портили масштаб
    ymax = df_plot['Price per kg (USD)'].quantile(0.95)
    fig.update_yaxes(range=[0, ymax])
    fig.update_layout(height=900, showlegend=True)
    fig.show()
else:
    print("Нет данных для построения графика динамики цен.")
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.35.2.min.js"></script>                <div id="cafea3ee-30b6-4817-85e5-071bc2e92317" class="plotly-graph-div" style="height:900px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("cafea3ee-30b6-4817-85e5-071bc2e92317")) {                    Plotly.newPlot(                        "cafea3ee-30b6-4817-85e5-071bc2e92317",                        [{"hovertemplate":"Exporter=China\u003cbr\u003eImporter=Canada\u003cbr\u003erefYear=%{x}\u003cbr\u003ePrice per kg (USD)=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"China","line":{"color":"#636efa","dash":"solid"},"marker":{"symbol":"circle"},"mode":"lines+markers","name":"China","orientation":"v","showlegend":true,"x":[2018,2019,2021,2022,2023,2024],"xaxis":"x3","y":[1.6236025388485398,1.6702304539917694,1.4739501022991106,1.537,1.5382819654571656,1.5340339292421925],"yaxis":"y3","type":"scatter"},{"hovertemplate":"Exporter=China\u003cbr\u003eImporter=India\u003cbr\u003erefYear=%{x}\u003cbr\u003ePrice per kg (USD)=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"China","line":{"color":"#636efa","dash":"solid"},"marker":{"symbol":"circle"},"mode":"lines+markers","name":"China","orientation":"v","showlegend":false,"x":[2018,2019,2020,2021,2022,2023,2024],"xaxis":"x2","y":[1.7144609552383077,1.445666641443511,1.1956657082088655,1.267354527716144,1.534830074305305,1.4287935483553555,1.336841871868408],"yaxis":"y2","type":"scatter"},{"hovertemplate":"Exporter=Italy\u003cbr\u003eImporter=Canada\u003cbr\u003erefYear=%{x}\u003cbr\u003ePrice per kg (USD)=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"Italy","line":{"color":"#EF553B","dash":"solid"},"marker":{"symbol":"circle"},"mode":"lines+markers","name":"Italy","orientation":"v","showlegend":true,"x":[2018,2019,2020,2021,2022,2023,2024],"xaxis":"x3","y":[1.6891670417481714,1.388272874651178,1.4164935899758553,1.277403103282005,1.602003656920078,1.6400061866503117,1.6593377937154687],"yaxis":"y3","type":"scatter"},{"hovertemplate":"Exporter=Italy\u003cbr\u003eImporter=India\u003cbr\u003erefYear=%{x}\u003cbr\u003ePrice per kg (USD)=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"Italy","line":{"color":"#EF553B","dash":"solid"},"marker":{"symbol":"circle"},"mode":"lines+markers","name":"Italy","orientation":"v","showlegend":false,"x":[2018,2019,2020,2021,2022,2023,2024],"xaxis":"x2","y":[1.2432755767790262,1.398926130053718,1.1710485443926961,1.2489138135557654,1.7058804430320151,1.3588427694520966,1.2440683025641024],"yaxis":"y2","type":"scatter"},{"hovertemplate":"Exporter=Italy\u003cbr\u003eImporter=Mozambique\u003cbr\u003erefYear=%{x}\u003cbr\u003ePrice per kg (USD)=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"Italy","line":{"color":"#EF553B","dash":"solid"},"marker":{"symbol":"circle"},"mode":"lines+markers","name":"Italy","orientation":"v","showlegend":false,"x":[2019,2020,2021,2022,2024],"xaxis":"x","y":[4.358333333333333,0.9995292327368154,19.494857142857143,24.662583333333334,1.7505726965279198],"yaxis":"y","type":"scatter"},{"hovertemplate":"Exporter=Mexico\u003cbr\u003eImporter=Canada\u003cbr\u003erefYear=%{x}\u003cbr\u003ePrice per kg (USD)=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"Mexico","line":{"color":"#00cc96","dash":"solid"},"marker":{"symbol":"circle"},"mode":"lines+markers","name":"Mexico","orientation":"v","showlegend":true,"x":[2018,2019,2020,2021,2022,2023,2024],"xaxis":"x3","y":[1.1136943797297616,1.4290223835804146,1.402130892533303,1.2651795320169446,1.6189284259931824,1.4063297731599063,1.3486393391354017],"yaxis":"y3","type":"scatter"},{"hovertemplate":"Exporter=Mexico\u003cbr\u003eImporter=India\u003cbr\u003erefYear=%{x}\u003cbr\u003ePrice per kg (USD)=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"Me ...

# %% [markdown]
# ### **8. Зеркальные данные по Италии (Mirror data)**

# %%
# Импорт Италии (зеркальные данные): другие страны сообщают, что экспортировали в ИТАЛИЮ
italy_import_mirror = df_clean[
    (df_clean['partnerISO'] == 'ITA') &
    (df_clean['flowDesc'] == 'Export')  # Экспорт → в Италию
].copy()

# Экспорт Италии (зеркальные данные): другие страны сообщают, что импортировали из ИТАЛИИ
italy_export_mirror = df_clean[
    (df_clean['partnerISO'] == 'ITA') &
    (df_clean['flowDesc'] == 'Import')  # Импорт ← из Италии
].copy()
if not italy_import_mirror.empty:
    # Агрегируем по поставщику
    suppliers = italy_import_mirror.groupby('reporterDesc').agg({
        'netWgt': 'sum',
        'primaryValue': 'sum'
    }).reset_index()

    suppliers['Price per kg (USD)'] = suppliers['primaryValue'] / suppliers['netWgt']
    suppliers = suppliers.sort_values('netWgt', ascending=False).head(10)

    # Визуализация
    fig = px.bar(
        suppliers,
        x='reporterDesc',
        y='netWgt',
        color='Price per kg (USD)',
        title='ТОП-10 поставщиков фтористого алюминия в Италию (зеркальные данные, 2018–2025)',
        labels={'reporterDesc': 'Страна-поставщик', 'netWgt': 'Объём (кг)'}
    )
    fig.update_xaxes(tickangle=-45)
    fig.show()
else:
    print("Нет зеркальных данных об импорте Италии за 2018–2025 гг.")
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.35.2.min.js"></script>                <div id="794e362c-7556-40d2-a1af-db59e82273e2" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("794e362c-7556-40d2-a1af-db59e82273e2")) {                    Plotly.newPlot(                        "794e362c-7556-40d2-a1af-db59e82273e2",                        [{"alignmentgroup":"True","hovertemplate":"Страна-поставщик=%{x}\u003cbr\u003eОбъём (кг)=%{y}\u003cbr\u003ePrice per kg (USD)=%{marker.color}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"","marker":{"color":[1.7895998611111112,4.403777788883019,1.832825960784314,3.3432799440348457,1.47,4.504636935730691,2.4190425160163076,1.7649253731343284,44.283419760199735,5.729138465877044],"coloraxis":"coloraxis","pattern":{"shape":""}},"name":"","offsetgroup":"","orientation":"v","showlegend":false,"textposition":"auto","x":["Estonia","Romania","Spain","Germany","China","USA","Netherlands","France","Belgium","Thailand"],"xaxis":"x","y":[576000.0,560296.0,204000.0,41534.416,25500.0,2006.821,1717.0,1072.0,364.47,283.68],"yaxis":"y","type":"bar"}],                        {"template":{"data":{"histogram2dcontour":[{"type":"histogram2dcontour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"choropleth":[{"type":"choropleth","colorbar":{"outlinewidth":0,"ticks":""}}],"histogram2d":[{"type":"histogram2d","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmap":[{"type":"heatmap","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmapgl":[{"type":"heatmapgl","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"contourcarpet":[{"type":"contourcarpet","colorbar":{"outlinewidth":0,"ticks":""}}],"contour":[{"type":"contour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"surface":[{"type":"surface","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"mesh3d":[{"type":"mesh3d","colorbar":{"outlinewidth":0,"ticks":""}}],"scatter":[{"fillpattern":{"fillmode":"overlay","size":10,"solidity":0.2},"type":"scatter"}],"parcoords":[{"type":"parcoords","line":{"colorbar":{"outlinewidth":0,"ticks ...
